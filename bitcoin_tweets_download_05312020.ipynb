# %%
import re 
import tweepy
import csv  #Import csv
import datetime
from tweepy import OAuthHandler

# %%
# Twitter API Keys
api_key = "Hy0aUV0SXc5CUwLU2Ai1I7SiA"
api_secret = "IJHnhyVrwLfSWfbHyFhfcEIzsC3hum7Aiqli31MnEhMwy5I3Wr"
access_token_key = "978314405124476928-nGj3pLqk08UMMxu2bmwtTo7YE6r4Dw5"
access_token_secret = "z0ZNUwA5TpNphIbtOhBhUDgumPHFpw5iIgmFkkeC2Rs2x"

auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token_key, access_token_secret)

api = tweepy.API(auth)
# Note: add this option on tweepy initializationwhen rate limit is reached:
# api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# Open/create a file to append data
csvFile = open('result.csv', 'a')

# Use csv writer
csvWriter = csv.writer(csvFile)

# Create a bitcoin tweet list
tweets = api.user_timeline(screen_name="bitcoin", count=200)
print("Number of tweets: {}.\n".format(len(tweets)))

# Print the latest 200 tweets:
print("200 recent tweets:\n")
for tweet in tweets[:200]:
    print(tweet.text)

    # Write a row to the CSV file
    # Use encode UTF-8
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
    print (tweet.created_at, tweet.text)
    print()
csvFile.close()
# Out:
# Number of tweets: 200.
#
# 200 recent tweets:
#
# @blockfolio Bitcoin fixes this.
# 2020-05-29 18:44:22 @blockfolio Bitcoin fixes this.
#
# RT @danheld: I’d like to take the time to thank the Bitcoin developers and Cypherpunks that made Bitcoin what is today:
#
# - Satoshi Nakamot…
# 2020-05-29 17:39:00 RT @danheld: I’d like to take the time to thank the Bitcoin developers and Cypherpunks that made Bitcoin what is today:
#
# - Satoshi Nakamot…
#
# Counterfeit $trillion
# the state doesn’t bat an eye.
#
#
#
# Counterfeit $20
#
# the state loses its mind.
# 2020-05-29 17:38:38 Counterfeit $trillion
# the state doesn’t bat an eye.
#
#
#
# Counterfeit $20
#
# the state loses its mind.
#
# #FF these Bitcoiners👇
#
# @StopAndDecrypt
# @100trillionUSD
# @proofofsteph
# @MsHodl
# @_JustinMoon_
# @pierre_rochard… https://t.co/2e4yvYylXQ
# 2020-05-29 17:33:23 #FF these Bitcoiners👇
#
# @StopAndDecrypt
# @100trillionUSD
# @proofofsteph
# @MsHodl
# @_JustinMoon_
# ...
